# %% [markdown]
# ## LIB and json load

# %%
import numpy as np
import pandas as pd
import json

# %%
# read destiny_database_integrated.json
with open ('./destiny_database_integrated.json','r',encoding='utf-8') as f:
    destiny_database_integrated = json.load(f)

# %%
# data frame
destiny_df = pd.read_json('./destiny_database_integrated.json')

# %%
destiny_df.head()
# Out:
#                    title                                           subtitle  \
# 0    The Gate Lord's Eye         It looks through you, toward the infinite.
# 1  The Lantern of Osiris                              A beacon through time
# 2       Warmind Khanjali       A ritual blade inlaid with digitized enigma.
# 3   Seed of Silver Wings  Malleable and hungering. Speak not of what it ...
# 4         Dark Heirlooms  An occult kibisis holding a shed tooth of the ...
#
#                                          description timestamp  keywords
# 0  An iris unfurls. Our gaze caught. Cortex clutc...       NaT       NaN
# 1  "I created the Sundial to rectify my greatest ...       NaT       NaN
# 2  [[Neuron-Sheath key]\n\n[Run through,\n\nTime ...       NaT       NaN
# 3  [GST-ENCODED=9: Sndr.1//MSTC\n\n[GST-ENCODED=9...       NaT       NaN
# 4  [Report by VanNet encrypted router.]\n\nZavala...       NaT       NaN

# %% [markdown]
# ## Legacy

# %%
destiny_df.head()
# Out:
#                    title                                           subtitle  \
# 0    The Gate Lord's Eye         It looks through you, toward the infinite.
# 1  The Lantern of Osiris                              A beacon through time
# 2       Warmind Khanjali       A ritual blade inlaid with digitized enigma.
# 3   Seed of Silver Wings  Malleable and hungering. Speak not of what it ...
# 4         Dark Heirlooms  An occult kibisis holding a shed tooth of the ...
#
#                                          description timestamp  keywords
# 0  An iris unfurls. Our gaze caught. Cortex clutc...       NaT       NaN
# 1  "I created the Sundial to rectify my greatest ...       NaT       NaN
# 2  [[Neuron-Sheath key]\n\n[Run through,\n\nTime ...       NaT       NaN
# 3  [GST-ENCODED=9: Sndr.1//MSTC\n\n[GST-ENCODED=9...       NaT       NaN
# 4  [Report by VanNet encrypted router.]\n\nZavala...       NaT       NaN

# %%
destiny_df.loc[0,'timestamp'] = 8000
destiny_df.loc[1,'timestamp'] = 9000
destiny_df.loc[2,'timestamp'] = 10000
destiny_df.loc[3,'timestamp'] = 11000
destiny_df.loc[4,'timestamp'] = 12000

# %%
destiny_df[5:20]
# Out:
#                         title  \
# 5   The Unclaimed Lightbearer
# 6             Cryptolith Lure
# 7           Bell of Conquests
# 8   Legacy: Hammer of Proving
# 9              Paradrome Cube
# 10   Legacy: Splicer Gauntlet
# 11        Wayfinder's Compass
# 12             Synaptic Spear
# 13        Nightmare Harvester
# 14               Skeleton Key
# 15              Seraph Cipher
# 16          Ascendant Scepter
# 17    NPA Repulsion Regulator
# 18                 Europa – 1
# 19                 Europa – 2
#
#                                              subtitle  \
# 5                            Transmission from Osiris
# 6                              Modified Hive Artifact
# 7    Hear the seventh strike, calling blades to meet.
# 8   Forge Challenger Medallions from Cabal Gold to...
# 9   A cube of living code claimed from the Vex dom...
# 10
# 11  The needle guides the thread to a goal. Obstac...
# 12  A lance aligned with the psychic plane, capabl...
# ...

# %%
destiny_df.loc[5,'timestamp'] = 12000
destiny_df.loc[6,'timestamp'] = 12000
destiny_df.loc[7,'timestamp'] = 13000
destiny_df.loc[8,'timestamp'] = 13000
destiny_df.loc[9,'timestamp'] = 14000
destiny_df.loc[10,'timestamp'] = 14000
destiny_df.loc[11,'timestamp'] = 15000
destiny_df.loc[12,'timestamp'] = 16000
destiny_df.loc[13,'timestamp'] = 17000
destiny_df.loc[14,'timestamp'] = 18000
destiny_df.loc[15,'timestamp'] = 19000
destiny_df.loc[16,'timestamp'] = 20000
destiny_df.loc[17,'timestamp'] = 21000

# %%
destiny_df.head(20)
# Out:
#                         title  \
# 0         The Gate Lord's Eye
# 1       The Lantern of Osiris
# 2            Warmind Khanjali
# 3        Seed of Silver Wings
# 4              Dark Heirlooms
# 5   The Unclaimed Lightbearer
# 6             Cryptolith Lure
# 7           Bell of Conquests
# 8   Legacy: Hammer of Proving
# 9              Paradrome Cube
# 10   Legacy: Splicer Gauntlet
# 11        Wayfinder's Compass
# 12             Synaptic Spear
# 13        Nightmare Harvester
# 14               Skeleton Key
# 15              Seraph Cipher
# 16          Ascendant Scepter
# 17    NPA Repulsion Regulator
# 18                 Europa – 1
# 19                 Europa – 2
#
#                                              subtitle  \
# 0          It looks through you, toward the infinite.
# 1                               A beacon through time
# 2        A ritual blade inlaid with digitized enigma.
# 3   Malleable and hungering. Speak not of what it ...
# ...

# %% [markdown]
# ## book Season 15

# %%
destiny_df[18:72]
# Out:
#                       title subtitle  \
# 18               Europa – 1
# 19               Europa – 2
# 20               Europa – 3
# 21               Europa – 4
# 22               Europa – 5
# 23               Europa – 6
# 24               Europa – 7
# 25               Europa – 8
# 26               Europa – 9
# 27                 Luna – 1
# 28                 Luna – 2
# 29                 Luna – 3
# 30                 Luna – 4
# 31                 Luna – 5
# 32                 Luna – 6
# 33                 Luna – 7
# 34                 Luna – 8
# 35                 Luna – 9
# 36               Nessus – 1
# 37               Nessus – 2
# 38               Nessus – 3
# 39               Nessus – 4
# 40               Nessus – 5
# 41               Nessus – 6
# 42               Nessus – 7
# 43               Nessus – 8
# 44               Nessus – 9
# 45  The Drowned Captain – 1
# 46  The Drowned Captain – 2
# 47  The Drowned Captain – 3
# 48  The Drowned Captain – 4
# ...

# %%
## sub title change
destiny_df.loc[18:45,'title'] = 'Book: Tales of the Forgotten – Vol. 1'
destiny_df.loc[45:71,'title'] = 'Book: Tales of the Forgotten – Vol. 2'
destiny_df.loc[18:26,'subtitle'] = ['Europa – 1','Europa - 2','Europa - 3','Europa - 4','Europa - 5','Europa - 6','Europa - 7','Europa - 8','Europa - 9']
destiny_df.loc[27:35,'subtitle'] = ['Luna - 1', 'Luna - 2', 'Luna - 3', 'Luna - 4', 'Luna - 5', 'Luna - 6', 'Luna - 7', 'Luna - 8', 'Luna - 9']
destiny_df.loc[36:44,'subtitle'] = ['Nessus - 1',' Nessus - 2',' Nessus - 3',' Nessus - 4',' Nessus - 5',' Nessus - 6',' Nessus - 7',' Nessus - 8',' Nessus - 9']
destiny_df.loc[45:53,'subtitle'] = ['The Drowned Captain - 1', 'The Drowned Captain - 2', 'The Drowned Captain - 3', 'The Drowned Captain - 4', 'The Drowned Captain - 5', 'The Drowned Captain - 6', 'The Drowned Captain - 7', 'The Drowned Captain - 8', 'The Drowned Captain - 9']
destiny_df.loc[54:61,'subtitle'] = ['Legion Lost - 10','Legion Lost - 11','Legion Lost - 12','Legion Lost - 13','Legion Lost - 14','Legion Lost - 15','Legion Lost - 16','Legion Lost - 17']
destiny_df.loc[62:71,'subtitle'] = ['Findings of Eido - 18', 'Findings of Eido - 19', 'Findings of Eido - 20', 'Findings of Eido - 21', 'Findings of Eido - 22', 'Findings of Eido - 23', 'Findings of Eido - 24', 'Findings of Eido - 25', 'Findings of Eido - 26', 'Findings of Eido - 27']

# %%
# book1
base_timestamp = 15101
for i in range(18, 45):
    destiny_df.loc[i, 'timestamp'] = base_timestamp
    base_timestamp += 1

# %%
destiny_df[18:72]
# Out:
#                                     title                 subtitle  \
# 18  Book: Tales of the Forgotten – Vol. 1               Europa – 1
# 19  Book: Tales of the Forgotten – Vol. 1               Europa - 2
# 20  Book: Tales of the Forgotten – Vol. 1               Europa - 3
# 21  Book: Tales of the Forgotten – Vol. 1               Europa - 4
# 22  Book: Tales of the Forgotten – Vol. 1               Europa - 5
# 23  Book: Tales of the Forgotten – Vol. 1               Europa - 6
# 24  Book: Tales of the Forgotten – Vol. 1               Europa - 7
# 25  Book: Tales of the Forgotten – Vol. 1               Europa - 8
# 26  Book: Tales of the Forgotten – Vol. 1               Europa - 9
# 27  Book: Tales of the Forgotten – Vol. 1                 Luna - 1
# 28  Book: Tales of the Forgotten – Vol. 1                 Luna - 2
# 29  Book: Tales of the Forgotten – Vol. 1                 Luna - 3
# 30  Book: Tales of the Forgotten – Vol. 1                 Luna - 4
# ...

# %% [markdown]
# ## book Season 18

# %%
# the drowned cap
best_timestamp = 18121
for i in range(45,72):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
destiny_df[45:73]
# Out:
#                                     title  \
# 45  Book: Tales of the Forgotten – Vol. 2
# 46  Book: Tales of the Forgotten – Vol. 2
# 47  Book: Tales of the Forgotten – Vol. 2
# 48  Book: Tales of the Forgotten – Vol. 2
# 49  Book: Tales of the Forgotten – Vol. 2
# 50  Book: Tales of the Forgotten – Vol. 2
# 51  Book: Tales of the Forgotten – Vol. 2
# 52  Book: Tales of the Forgotten – Vol. 2
# 53  Book: Tales of the Forgotten – Vol. 2
# 54  Book: Tales of the Forgotten – Vol. 2
# 55  Book: Tales of the Forgotten – Vol. 2
# 56  Book: Tales of the Forgotten – Vol. 2
# 57  Book: Tales of the Forgotten – Vol. 2
# 58  Book: Tales of the Forgotten – Vol. 2
# 59  Book: Tales of the Forgotten – Vol. 2
# 60  Book: Tales of the Forgotten – Vol. 2
# 61  Book: Tales of the Forgotten – Vol. 2
# 62  Book: Tales of the Forgotten – Vol. 2
# 63  Book: Tales of the Forgotten – Vol. 2
# 64  Book: Tales of the Forgotten – Vol. 2
# 65  Book: Tales of the Forgotten – Vol. 2
# ...

# %% [markdown]
# ## ITEMS Season 1 ~ 3

# %%
# 72 ~ 119
destiny_df[72:120]
# Out:
#                                    title  \
# 72              Grips of the Ace-Defiant
# 73               Vest of the Ace-Defiant
# 74                        Shadow's Cloak
# 75               Helm of the Ace-Defiant
# 76              Boots of the Ace-Defiant
# 77         Gloves of the Emperor's Agent
# 78           Vest of the Emperor's Agent
# 79          Cloak of the Emperor's Agent
# 80           Mask of the Emperor's Agent
# 81          Boots of the Emperor's Agent
# 82                        Cloak Judgment
# 83                      Cloak Relentless
# 84                Young Ahamkara's Spine
# 85              Mechaneer's Tricksleeves
# 86                           Raiden Flux
# 87                       Lucky Raspberry
# 88                   The Dragon's Shadow
# 89                     Knucklehead Radar
# 90                   Celestial Nighthawk
# 91                             Foetracer
# 92                           Lucky Pants
# 93                           Orpheus Rig
# ...

# %%
destiny_df.loc[72:76,'timestamp'] = 1600
destiny_df.loc[77:95,'timestamp'] = 1000
destiny_df.loc[98,'timestamp'] = 1000
destiny_df.loc[101:119,'timestamp'] = 1000

# %%
# 120 ~ 130
destiny_df[120:131]
# Out:
#                            title  \
# 120          Doom Fang Pauldrons
# 121                   Synthoceps
# 122          Crest of Alpha Lupi
# 123               Actium War Rig
# 124             Hallowfire Heart
# 125  An Insurmountable Skullfort
# 126        Mask of the Quiet One
# 127                 Lion Rampant
# 128                 Peacekeepers
# 129                 Dunemarchers
# 130          Noble Constant Mark
#
#                                               subtitle  \
# 120                              Nobody calls it that.
# 121  Caution: the organism has been known to develo...
# 122  Whoever survives our passing does so only by o...
# 123  Conflict Resolution Solution #3479: Leave them...
# 124  "You who seek the Forge: your journey will be ...
# 125  BRAINVAULT Sigma-ACTIUM-IX Cranial Dreadnought...
# 126                                                "…"
# 127  All expect that you should rouse yourself, as ...
# 128  Designed for the seamless delivery of justice ...
# ...

# %%
destiny_df.loc[120:130,'timestamp'] = 1000

# %%
# 130 ~ 150
destiny_df[131:151]
# Out:
#                                    title  \
# 131                           Classified
# 132                           Classified
# 133                   Brave Titan's Mark
# 134                           Classified
# 135                           Classified
# 136              Wraps of the Fulminator
# 137              Robes of the Fulminator
# 138                        Shadow's Bond
# 139               Mask of the Fulminator
# 140              Boots of the Fulminator
# 141      Wraps of the Emperor's Minister
# 142      Robes of the Emperor's Minister
# 143       Bond of the Emperor's Minister
# 144  Headpiece of the Emperor's Minister
# 145      Boots of the Emperor's Minister
# 146                        Bond Judgment
# 147                      Bond Relentless
# 148                           Sunbracers
# 149                    Karnstein Armlets
# 150                       Winter's Guile
#
#                                               subtitle  \
# ...

# %%
destiny_df.loc[133,'timestamp'] = 1000
destiny_df.loc[136:145,'timestamp'] = 1600
destiny_df.loc[146:150,'timestamp'] = 1000

# %%
# 150 ~ 170
destiny_df[151:171]
# Out:
#                       title  \
# 151       Starfire Protocol
# 152    Wings of Sacred Dawn
# 153  Skull of Dire Ahamkara
# 154       Crown of Tempests
# 155    Eye of Another World
# 156           Nezarec's Sin
# 157      Transversive Steps
# 158       Lunafaction Boots
# 159          Ego Talon Bond
# 160              Classified
# 161              Classified
# 162     Wise Warlock's Bond
# 163              Classified
# 164              Classified
# 165              Arcstrider
# 166              Gunslinger
# 167            Nightstalker
# 168                 Striker
# 169              Sunbreaker
# 170                Sentinel
#
#                                               subtitle  \
# 151  13.4 billion years ago, the first stars kindle...
# 152  There will come a day when the light will neve...
# 153  Reality is the finest flesh, oh bearer mine. A...
# 154  Mighty are they of the stormcloud thrones, and...
# 155  When the universe conspires, its enemies canno...
# ...

# %%
destiny_df.loc[151:159,'timestamp'] = 1000
destiny_df.loc[162,'timestamp'] = 1000
destiny_df.loc[165:170,'timestamp'] = 1000

# %%
# 170 ~ 190
destiny_df[171:191]
# Out:
#                         title  \
# 171               Stormcaller
# 172                 Dawnblade
# 173                Voidwalker
# 174         Way of the Outlaw
# 175   Way of the Sharpshooter
# 176   Way of the Sharpshooter
# 177        Way of the Warrior
# 178           Way of the Wind
# 179
# 180        Way of the Trapper
# 181     Way of the Pathfinder
# 182     Way of the Pathfinder
# 183   Code of the Fire-Forged
# 184  Code of the Siegebreaker
# 185
# 186   Code of the Earthshaker
# 187    Code of the Juggernaut
# 188
# 189     Code of the Protector
# 190     Code of the Aggressor
#
#                                               subtitle  \
# 171                 Harmony within, hurricane without.
# 172          Spread your wings and set the sky ablaze.
# 173  Those who have stared into the Void are not bo...
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
#
# ...

# %%
destiny_df.loc[171:190,'timestamp'] = 1000

# %%
# 190 ~ 210
destiny_df[191:211]
# Out:
#                           title  \
# 191
# 192           Attunement of Sky
# 193         Attunement of Flame
# 194    Attunement of Conduction
# 195  Attunement of the Elements
# 196         Attunement of Chaos
# 197        Attunement of Hunger
# 198          Eriana's Vengeance
# 199             Symmetry Flight
# 200              Takanome Wings
# 201               Ego and Squid
# 202               The Bandwagon
# 203               Rose and Bone
# 204             Vanishing Point
# 205                 Dinas Emrys
# 206                   Hastilude
# 207                Ghost Primus
# 208               Midnight Coup
# 209
# 210           Inaugural Address
#
#                                               subtitle  \
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198  "Wei… I will see you again. But first… I have ...
# 199  "To have Light, we must have Dark. This is the...
# 200  "Follow the blue flowers to the City. And know...
# 201  Pahanin was a Hunter, satirist, travel writer,...
# ...

# %%
destiny_df.loc[192:206,'timestamp'] = 1000
destiny_df.loc[207:208,'timestamp'] = 1600
destiny_df.loc[210,'timestamp'] = 1600
# destiny_df.loc[209,'timestamp'] = 'NaT' 이것때문에 timestamp 오류가 났었음

# %%
# 210 ~ 230
destiny_df[211:231]
# Out:
#                  title                                           subtitle  \
# 211   Sins of the Past  What once was old shall be knew again, and his...
# 212        Conspirator  Did Ghaul always dream of a republic? What ter...
# 213     Alone as a God  I am the perfect loving god, and all will trem...
# 214        Mob Justice  Life offers few greater pleasures than to humi...
# 215     It Stared Back  At the edge of the universe, I stared into the...
# 216         Prosecutor  "All this in service of one purpose. You have ...
# 217           Judgment  "The greatest threat to a Guardian is another ...
# 218         Relentless         "Embrace your fate." —Emissary of the Nine
# 219            The End  "Show them that safe harbor is very far away."...
# 220     A Sudden Death  "Everything dies. This is proof." —Emissary of...
# 221    A Swift Verdict         "Judgment is final." —Emissary of the Nine
# 222      The Long Walk  "There is an end to everything." —Emissary of ...
# ...

# %%
destiny_df.loc[211:215,'timestamp'] = 1600
destiny_df.loc[216:225,'timestamp'] = 1000

# %%
# 230 ~ 250
destiny_df[231:251]
# Out:
#                   title                                           subtitle  \
# 231      It Stared Back  At the edge of the universe, I stared into the...
# 232           Coldheart  Leverages liquid fuel veins as self-coolant to...
# 233      Sweet Business                                  "…I love my job."
# 234           Merciless                             Entropy is inevitable.
# 235       Fighting Lion  "I call it the Zhang Fei. It hits almost as ha...
# 236      The Prospector                  "Some things should stay buried."
# 237               Sturm  These ancient ceremonial pistols can be dated ...
# 238             Sunshot              "Can't outrun the sunrise." —Liu Feng
# 239      Vigilance Wing  "The eye remains open. The Lighthouse remains ...
# 240      Graviton Lance  Think of space-time as a tapestry on a loom. T...
# 241  The Wardcliff Coil  Ingenuity. Desperation. A haphazard prototype ...
# ...

# %%
destiny_df.loc[231,'timestamp'] = 1600
destiny_df.loc[232:250,'timestamp'] = 1000

# %%
# 250 ~ 270
destiny_df[251:271]
# Out:
#                  title                                           subtitle  \
# 251         Hard Light  Ionized polymer synballistic attack platform. ...
# 252    MIDA Multi-Tool  Select application: Ballistic engagement. Entr...
# 253      Retrofuturist                  They were so optimistic about us.
# 254   Grips of Feltroc  "There's something very settling about sleepin...
# 255    Vest of Feltroc  "The Loyalists won't be ready until every worl...
# 256   Cloak of Feltroc  "I can outshoot anybody. Even the Traveler-spa...
# 257    Mask of Feltroc  "I can solve this. Give me a weapon." —Feltroc...
# 258   Boots of Feltroc  "The Clipse worship guns. That's why Rull and ...
# 259
# 260
# 261    Kairos Function  "Some speculate that the radiolarian fluid is ...
# 262
# 263
# 264         Aeon Swift  "We are unique emanations of the same shared L...
# 265      Gemini Jester  "I love making people laugh. And by 'people,' ...
# ...

# %%
destiny_df.loc[251:253,'timestamp'] = 1000
destiny_df.loc[254:258,'timestamp'] = 2600
destiny_df.loc[261,'timestamp'] = 2000
destiny_df.loc[264:267,'timestamp'] = 2000
destiny_df.loc[268:270,'timestamp'] = 2600

# %%
# 270 ~ 290
destiny_df[271:291]
# Out:
#                    title                                           subtitle  \
# 271         Mask of Nohr  "I'm a Valus before I'm a 'Shadow.' But Calus ...
# 272      Greaves of Nohr  "Under Calus, this system will unite. And when...
# 273
# 274
# 275      Kairos Function  "Some speculate that the radiolarian fluid is ...
# 276
# 277
# 278            Aeon Safe  "We are unique emanations of the same shared L...
# 279        Khepri's Horn  "I pushed the sun. I can push you, too." —Insc...
# 280     Helm of Saint-14  "He walked out into the demon light. But at th...
# 281  Mk. 44 Stand-Asides                         Pardon me. Coming through.
# 282      Wraps of Sekris  "My stealth skin kept me secret. I just watche...
# 283      Robes of Sekris  "There was a sixth Light. He cut me and I cut ...
# 284       Bond of Sekris  "I never forgot what I saw—the gift the Great ...
# 285       Mask of Sekris  "Five Lights. Too many to fight. I loosed web ...
# ...

# %%
destiny_df.loc[271:272,'timestamp'] = 2600
destiny_df.loc[275,'timestamp'] = 2000
destiny_df.loc[278:281,'timestamp'] = 2000
destiny_df.loc[282:286,'timestamp'] = 2600
destiny_df.loc[289,'timestamp'] = 2000

# %%
# 290 ~ 310
destiny_df[291:311]
# Out:
#                           title  \
# 291
# 292                   Aeon Soul
# 293            Vesper of Radius
# 294             Ophidian Aspect
# 295                    The Stag
# 296                      Zephyr
# 297              Sagira's Shell
# 298          Winter Lotus Shell
# 299              Star Map Shell
# 300                Cosmos Shell
# 301             Fast Lane Shell
# 302       Fire Victorious Shell
# 303           Electronica Shell
# 304           Contender's Shell
# 305               Trichromatica
# 306             Sails of Osiris
# 307      Saint-14's Gray Pigeon
# 308          Kabr's Glass Aegis
# 309  Asher Mir's One-Way Ticket
# 310             Ikora's Resolve
#
#                                               subtitle  \
# 291
# 292  "We are unique emanations of the same shared L...
# 293  "Drawn like so, the Rift circle reinscribes pl...
# 294                     "Have I the aspic in my lips?"
# 295  Only bones for your feast. Only death for my v...
# ...

# %%
destiny_df.loc[292:310,'timestamp'] = 2000
destiny_df.loc[304,'timestamp'] = 2600

# %%
# 310 ~ 330 
destiny_df[311:331]
# Out:
#                              title  \
# 311  The Sundaresh Experiment 13-R
# 312         A History of Starlight
# 313                 Cerulean Flash
# 314         Universal Wavefunction
# 315                SV-112 Predator
# 316                Concentric Dawn
# 317             Curse of Foresight
# 318                Chill of Winter
# 319                  Holiday Cheer
# 320                     Undefeated
# 321                     Undeterred
# 322                      Tilt Fuse
# 323                Impact Velocity
# 324                     I Am Alive
# 325            Zenith of Your Kind
# 326                Null Calamity 9
# 327                  Machina Dei 4
# 328               Infinite Paths 8
# 329               Garden Progeny 1
# 330              West of Sunfall 7
#
#                                               subtitle  \
# 311  Ishtar Collective research led to places unexp...
# 312  Before Tyra Karn settled in the Iron Temple, h...
# ...

# %%
destiny_df.loc[311:330,'timestamp'] = 2000
destiny_df.loc[324:325,'timestamp'] = 2600

# %%
# 330 ~ 350
destiny_df[331:351]
# Out:
#                       title  \
# 331       Jack Queen King 3
# 332   Traveler's Judgment 5
# 333         The Conqueror 2
# 334            Sol Pariah 6
# 335         Perfect Paradox
# 336          Future Safe 10
# 337      Peace by Consensus
# 338         Prometheus Lens
# 339              The Colony
# 340                 Crimson
# 341                 Telesto
# 342         The Jade Rabbit
# 343         Silicon Neuroma
# 344                  D.F.A.
# 345              Duty Bound
# 346  The Unsolvable Problem
# 347       The Machine Child
# 348          The First Idea
# 349           The Black Box
# 350       The Ghost Synapse
#
#                                               subtitle  \
# 331  An army meets, and stands, and falls. Three no...
# 332  A visitor ignites the sky, and in the truth of...
# 333  To Tower comes a war in red; an orphan sounds ...
# 334  Amid the endless death one flew—unnatural all-...
# 335  A tale that's different from the rest: the thr...
# ...

# %%
destiny_df.loc[331:345,'timestamp'] = 2000
destiny_df.loc[346:350,'timestamp'] = 3000

# %%
# 350 ~ 370
destiny_df[351:371]
# Out:
#                     title                                           subtitle  \
# 351    The Emperor's Envy            The son's ambition will be his undoing.
# 352    Last of the Legion  "Vex technology on Mercury. Energy on Mars. Th...
# 353      Motion to Vacate                           "Done cannot be undone."
# 354      Motion to Compel                              "Take the long view."
# 355    Motion to Suppress                   "Present your truths carefully."
# 356         Polaris Lance  "I've forgotten so much of my past life, of my...
# 357       The Huckleberry   Nothin' in the world that 30 rounds can't solve.
# 358        Worldline Zero   A single strike can alter the course of history.
# 359          SUROS Regime  Nostalgia as a weapon of war. Style as a hallm...
# 360      Sleeper Simulant  Subroutine IKELOS: Status=complete. MIDNIGHT E...
# 361   Whisper of the Worm  A Guardian's power makes a rich feeding ground...
# ...

# %%
destiny_df.loc[351:352,'timestamp'] = 3600
destiny_df.loc[353:366,'timestamp'] = 3000

# %%
# 370 ~ 390
destiny_df[371:391]
# Out:
#                        title  \
# 371        Redrix's Claymore
# 372      Equitis Shade Grips
# 373        Equitis Shade Rig
# 374      Equitis Shade Cloak
# 375       Equitis Shade Cowl
# 376      Equitis Shade Boots
# 377           Ophidia Spathe
# 378           Wormhusk Crown
# 379   Sealed Ahamkara Grasps
# 380                Fr0st-EE5
# 381
# 382
# 383  BrayTech Survival Mitts
# 384     BrayTech Combat Vest
# 385    BrayTech Winter Cloak
# 386         BrayTech Sn0Mask
# 387       BrayTech Sn0Treads
# 388
# 389
# 390
#
#                                               subtitle  \
# 371  "On the ladder and in the fight, momentum is t...
# 372  "Ace pilots. Assassination squads. Swift thiev...
# 373  "A little faster. A little more lethal. You ar...
# 374  "This serves as a message to all false Cabal t...
# 375  "You have truly grown fat from strength. And y...
# 376  "There has only been a single Shadow from each...
# 377  Listen carefully when the serpent speaks, for ...
# ...

# %%
destiny_df.loc[371:380,'timestamp'] = 3000
destiny_df.loc[372:376,'timestamp'] = 3600
destiny_df.loc[383:387,'timestamp'] = 3000

# %%
# 390 ~ 410
destiny_df[391:411]
# Out:
#                           title  \
# 391
# 392
# 393                 Qiao's Care
# 394                Qiao's Heart
# 395              Qiao's Passing
# 396                 Qiao's Grin
# 397              Qiao's Strides
# 398      Turris Shade Gauntlets
# 399          Turris Shade Plate
# 400           Turris Shade Mark
# 401           Turris Shade Helm
# 402        Turris Shade Greaves
# 403                  Ashen Wake
# 404              Wormgod Caress
# 405           The Armamentarium
# 406             Eternal Warrior
# 407
# 408
# 409      BrayTech Thermal Grips
# 410  BrayTech Iron-Heart Engine
#
#                                               subtitle  \
# 391
# 392
# 393   "Always reach for understanding and compassion."
# 394  "Be aware at all times of what drives those ar...
# 395     "Bind yourself with compassion and knowledge."
# 396  "Let the outside mirror what is found on the i...
# 397  "Walk in peace, and know that there can be no ...
# ...

# %%
destiny_df.loc[393:397,'timestamp'] = 3000
destiny_df.loc[398:402,'timestamp'] = 3600
destiny_df.loc[403:406,'timestamp'] = 3000
destiny_df.loc[409:410,'timestamp'] = 3000

# %%
# 410 ~ 430
destiny_df[411:431]
# Out:
#                            title  \
# 411  BrayTech Absolute Zero Mark
# 412             BrayTech Sn0Helm
# 413            BrayTech Sn0Boots
# 414
# 415
# 416
# 417
# 418
# 419              Hardy's Control
# 420              Hardy's Journey
# 421               Hardy's Orders
# 422                 Hardy's Calm
# 423                Hardy's Steps
# 424         Insigne Shade Gloves
# 425          Insigne Shade Robes
# 426           Insigne Shade Bond
# 427          Insigne Shade Cover
# 428          Insigne Shade Boots
# 429             Sanguine Alchemy
# 430                Verity's Brow
#
#                                               subtitle  \
# 411                        Easy to spot in a whiteout.
# 412           The perfect way to avoid a brain freeze.
# 413  "Nonslip techno treads for maximum arctic mobi...
# 414
# 415
# 416
# 417
# 418
# 419  "You know what I believe? Whatever I can get m...
# 420  "Listen closely to those deep, distant warning...
# ...

# %%
destiny_df.loc[411:413,'timestamp'] = 3000
destiny_df.loc[419:430,'timestamp'] = 3000
destiny_df.loc[424:428,'timestamp'] = 3600

# %%
# 430 ~ 450
destiny_df[431:451]
# Out:
#                             title  \
# 431             Claws of Ahamkara
# 432               Apotheosis Veil
# 433
# 434
# 435  BrayTech Researcher's Gloves
# 436   BrayTech Researcher's Robes
# 437    BrayTech Researcher's Bond
# 438    BrayTech Researcher's Hood
# 439   BrayTech Researcher's Boots
# 440
# 441
# 442
# 443
# 444
# 445       Mihaylova's Instruments
# 446            Mihaylova's Choice
# 447              Mihaylova's Tale
# 448           Mihaylova's Triumph
# 449              Mihaylova's Path
# 450         Alchemical Dawn Shell
#
#                                               subtitle  \
# 431  The mind is malleable, filled with transient a...
# 432  Most helmets protect the mind from the univers...
# 433
# 434
# 435                            Warm hands, warm heart.
# 436  I tend to work better while not freezing to de...
# 437          Keeping our greatest minds safe and warm.
# 438  Featuring the latest in autocorrecting lens te...
# ...

# %%
destiny_df.loc[431:432,'timestamp'] = 3000
destiny_df.loc[435:439,'timestamp'] = 3000
destiny_df.loc[445:450,'timestamp'] = 3100

# %%
# 450 ~ 500
destiny_df[451:501]
# Out:
#                                 title  \
# 451              Knight's Peace Shell
# 452            Skyline Flipside Shell
# 453               Iris Pulsator Shell
# 454             Bursting Wisdom Shell
# 455                       Lost Legend
# 456                   Shadow Trespass
# 457                  Holborn's Splint
# 458                     Stark Baffler
# 459                Zavala's Authority
# 460                         Eon Drive
# 461                         Otherside
# 462                        Vespulaser
# 463           G-335 Anseris Overdrive
# 464                     Azure Azazyel
# 465       Solstice Grasps (Rekindled)
# 466         Solstice Vest (Rekindled)
# 467        Solstice Cloak (Rekindled)
# 468         Solstice Mask (Rekindled)
# 469      Solstice Strides (Rekindled)
# 470     Solstice Grasps (Resplendent)
# 471       Solstice Vest (Resplendent)
# 472      Solstice Cloak (Resplendent)
# 473       Solstice Mask (Resplendent)
# ...

# %%
destiny_df.loc[451:499,'timestamp'] = 3000
destiny_df.loc[465:494,'timestamp'] = 3700
destiny_df.loc[497,'timestamp'] = 3700
destiny_df.loc[499,'timestamp'] = 3700

# %%
# 500 ~ 510
destiny_df[501:510]
# Out:
#                   title                                           subtitle  \
# 501
# 502
# 503
# 504
# 505
# 506         Gray Hornet  This Sparrow zips and dives and comes in for t...
# 507    Blacklight Razor  Mounted with harmonized twin pulse engines for...
# 508    Comrades in Arms  None of us can do it alone. And none of us sho...
# 509  Spicy Ramen Coupon      Spicy Ramen. Large. 5 stars. Extra dumplings.
#
#                                            description timestamp  keywords
# 501                                                          NaT       NaN
# 502                                                          NaT       NaN
# 503                                                          NaT       NaN
# 504                                                          NaT       NaN
# 505                                                          NaT       NaN
# 506  "Does that thing fly?"\n\n"Why would you ask t...       NaT       NaN
# ...

# %%
destiny_df.loc[506:507,'timestamp'] = 3000
destiny_df.loc[508,'timestamp'] = 3700
destiny_df.loc[509,'timestamp'] = 3000

# %% [markdown]
# ## Book season 4

# %%
# 510 ~ 640 Lore of Destiny
destiny_df[510:551]
# Out:
#                                title subtitle  \
# 510   The Length of a Chain | Part I
# 511  The Length of a Chain | Part II
# 512             At the Gate | Part I
# 513            At the Gate | Part II
# 514                 Through the Gate
# 515                    In the Garden
# 516                      On the Hunt
# 517         After the Heart | Part I
# 518        After the Heart | Part II
# 519                           Jolyon
# 520                   After the Fall
# 521                            Kings
# 522                 Fanatic | Part I
# 523                Fanatic | Part II
# 524                    The Severance
# 525                           Fikrul
# 526                          Docking
# 527                            Petra
# 528                    Free | Part I
# 529                   Free | Part II
# 530                A Gift of Madness
# 531          By Thy Tongue Be Damned
# 532                Riddled with Lies
# 533                Anguish, Ten-Fold
# ...

# %%
# col list
sub_list = list(destiny_df.loc[510:637,'title'])

print(sub_list)
# Out:
# ['The Length of a Chain | Part I', 'The Length of a Chain | Part II', 'At the Gate | Part I', 'At the Gate | Part II', 'Through the Gate', 'In the Garden', 'On the Hunt', 'After the Heart | Part I', 'After the Heart | Part II', 'Jolyon', 'After the Fall', 'Kings', 'Fanatic | Part I', 'Fanatic | Part II', 'The Severance', 'Fikrul', 'Docking', 'Petra', 'Free | Part I', 'Free | Part II', 'A Gift of Madness', 'By Thy Tongue Be Damned', 'Riddled with Lies', 'Anguish, Ten-Fold', 'A Blind Eye Toward Tomorrow', 'The Ragged Valley Sprint', 'Truth Tinkered', 'An Evolution of Faith', 'A Scorned Path', 'These Bad Lands', 'No Heroes Here', 'The Lonely and the Dead', 'The Sad Story of Eldred Rush', 'Gotta Do More Than Shoot', 'Deal', 'Call', 'First Stake', 'Fold', 'Flop', 'Raise', 'Turn', 'All-In', 'River', 'Showdown', 'Winner Take All', 'Bluff', 'Bad Beat', 'Throne', 'Oracle', 'Misraaks', 'Azirim', 'Bamberga', 'Letters', 'Honored', 'Riven', 'Reextinction', 'Savin', 'Archiloquy', 'Brephos I', 'Bre
# ...

# %%
# subtitle change
destiny_df.loc[510:637,'subtitle'] = sub_list

# %%
# title change
destiny_df.loc[510:637,'title'] = 'Book: The Forsaken Prince'

# %%
# page Book: The Forsaken Prince
# the drowned cap
best_timestamp = 4001
for i in range(510,529+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
# title change
destiny_df.loc[530:643,'title'] = 'Book: The Lawless Frontier'

# %%
# page 'Book: The Lawless Frontier'
best_timestamp = 4020 + 1
for i in range(530,543+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
save_df = destiny_df.copy(deep=True)

# %%
# Book: The Man They Call Cayde
destiny_df[544:557]
# Out:
#                           title         subtitle  \
# 544  Book: The Lawless Frontier             Deal
# 545  Book: The Lawless Frontier             Call
# 546  Book: The Lawless Frontier      First Stake
# 547  Book: The Lawless Frontier             Fold
# 548  Book: The Lawless Frontier             Flop
# 549  Book: The Lawless Frontier            Raise
# 550  Book: The Lawless Frontier             Turn
# 551  Book: The Lawless Frontier           All-In
# 552  Book: The Lawless Frontier            River
# 553  Book: The Lawless Frontier         Showdown
# 554  Book: The Lawless Frontier  Winner Take All
# 555  Book: The Lawless Frontier            Bluff
# 556  Book: The Lawless Frontier         Bad Beat
#
#                                            description timestamp  keywords
# 544  All joking aside—maybe I've made mistakes. May...       NaT       NaN
# 545  Now, to be clear, yeah, the plan is to tell it...       NaT       NaN
# ...

# %%
destiny_df.loc[544:557,'title'] = 'Book: The Man They Call Cayde'

# %%
# page ''Book: The Man They Call Cayde'
best_timestamp = 4034 +1
for i in range(544,556+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
# Book: Book: The Dreaming City
destiny_df[556:567]
# Out:
#                              title      subtitle  \
# 556  Book: The Man They Call Cayde      Bad Beat
# 557  Book: The Man They Call Cayde        Throne
# 558     Book: The Lawless Frontier        Oracle
# 559     Book: The Lawless Frontier      Misraaks
# 560     Book: The Lawless Frontier        Azirim
# 561     Book: The Lawless Frontier      Bamberga
# 562     Book: The Lawless Frontier       Letters
# 563     Book: The Lawless Frontier       Honored
# 564     Book: The Lawless Frontier         Riven
# 565     Book: The Lawless Frontier  Reextinction
# 566     Book: The Lawless Frontier         Savin
#
#                                            description timestamp  keywords
# 556  Been trying hard to give you a sense of what m...      4047       NaN
# 557  Eris Morn returned to the Vestian Outpost. Bec...       NaT       NaN
# 558  There came a morning when the Techeuns spoke i...       NaT       NaN
# ...

# %%
destiny_df.loc[557:566,'title'] = 'Book: The Dreaming City'

# %%
# page ''Book: The Dreaming City'
best_timestamp = 4047 +1
for i in range(557,566+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
# book 'Book: Marasenna'
destiny_df[566:594]
# Out:
#                           title          subtitle  \
# 566     Book: The Dreaming City             Savin
# 567  Book: The Lawless Frontier        Archiloquy
# 568  Book: The Lawless Frontier         Brephos I
# 569  Book: The Lawless Frontier        Brephos II
# 570  Book: The Lawless Frontier       Brephos III
# 571  Book: The Lawless Frontier       Cosmogyre I
# 572  Book: The Lawless Frontier      Cosmogyre II
# 573  Book: The Lawless Frontier     Cosmogyre III
# 574  Book: The Lawless Frontier      Cosmogyre IV
# 575  Book: The Lawless Frontier      Ecstasiate I
# 576  Book: The Lawless Frontier     Ecstasiate II
# 577  Book: The Lawless Frontier    Ecstasiate III
# 578  Book: The Lawless Frontier       Fideicide I
# 579  Book: The Lawless Frontier      Fideicide II
# 580  Book: The Lawless Frontier     Fideicide III
# 581  Book: The Lawless Frontier       Heresiology
# 582  Book: The Lawless Frontier        Imponent I
# 583  Book: The Lawless Frontier       Imponent II
# ...

# %%
destiny_df.loc[567:593,'title'] = 'Book: Marasenna'

# %%
# page 'Book: Marasenna'
best_timestamp = 4057 +1
for i in range(567,593+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
# book Book: Truth to Power
destiny_df[593:611]
# Out:
#                           title          subtitle  \
# 593             Book: Marasenna        Revanche I
# 594  Book: The Lawless Frontier        Is it you?
# 595  Book: The Lawless Frontier   Will you smile?
# 596  Book: The Lawless Frontier            Medusa
# 597  Book: The Lawless Frontier      Thetis Brave
# 598  Book: The Lawless Frontier  act|choose|react
# 599  Book: The Lawless Frontier         Injection
# 600  Book: The Lawless Frontier         Thank you
# 601  Book: The Lawless Frontier          YOU MUST
# 602  Book: The Lawless Frontier  react|choose|act
# 603  Book: The Lawless Frontier            asudeM
# 604  Book: The Lawless Frontier     It's just me.
# 605  Book: The Lawless Frontier       Revanche II
# 606  Book: The Lawless Frontier      Revanche III
# 607  Book: The Lawless Frontier       Revanche IV
# 608  Book: The Lawless Frontier        Revanche V
# 609  Book: The Lawless Frontier           Telic I
# 610  Book: The Lawless Frontier          Telic II
#
# ...

# %%
destiny_df.loc[594:604,'title'] = 'Book: Truth to Power'

# %%
# page 'Book: Marasenna'
best_timestamp = 4084 +1
for i in range(594,604+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
# book Book: The Awoken of the Reef
destiny_df[604:628]
# Out:
#                           title               subtitle  \
# 604        Book: Truth to Power          It's just me.
# 605  Book: The Lawless Frontier            Revanche II
# 606  Book: The Lawless Frontier           Revanche III
# 607  Book: The Lawless Frontier            Revanche IV
# 608  Book: The Lawless Frontier             Revanche V
# 609  Book: The Lawless Frontier                Telic I
# 610  Book: The Lawless Frontier               Telic II
# 611  Book: The Lawless Frontier          Tyrannocide I
# 612  Book: The Lawless Frontier         Tyrannocide II
# 613  Book: The Lawless Frontier        Tyrannocide III
# 614  Book: The Lawless Frontier         Tyrannocide IV
# 615  Book: The Lawless Frontier          Tyrannocide V
# 616  Book: The Lawless Frontier                 Regent
# 617  Book: The Lawless Frontier                  Illyn
# 618  Book: The Lawless Frontier               Nitrogen
# 619  Book: The Lawless Frontier                Refusal
# ...

# %%
# title
destiny_df.loc[605:627,'title'] = 'Book: The Awoken of the Reef'

# %%
# page 'Book: The Awoken of the Reef'
best_timestamp = 4095 +1
for i in range(605,627+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
destiny_df[627:638]
# Out:
#                             title                          subtitle  \
# 627  Book: The Awoken of the Reef                          Emissary
# 628    Book: The Lawless Frontier                    Uneasy Feeling
# 629    Book: The Lawless Frontier                   Justified Means
# 630    Book: The Lawless Frontier               Step into the Shade
# 631    Book: The Lawless Frontier         Artifacts and Old Friends
# 632    Book: The Lawless Frontier                  Shadow on a Wall
# 633    Book: The Lawless Frontier         Bright Side of a Bad Idea
# 634    Book: The Lawless Frontier  The Price of a Double-Sided Coin
# 635    Book: The Lawless Frontier              Checking the Chamber
# 636    Book: The Lawless Frontier                 A Matter of Trust
# 637    Book: The Lawless Frontier                      The Long Con
#
#                                            description timestamp  keywords
# 627  the clever one sees through our pawn\n\n'I am ...      4118       NaN
# ...

# %%
# title
destiny_df.loc[628:637,'title'] = 'Book: A Drifter\'s Gambit'

# %%
# page 'Book: A Drifter's Gambit'
best_timestamp = 4118 +1
for i in range(628,637+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
destiny_df[666:702]
# Out:
#                                 title subtitle  \
# 666                          Pressure
# 667                      Ghost Hunter
# 668               The Chosen's Choice
# 669                  The We Before Us
# 670               Don't Call Me Ghost
# 671                       Compliments
# 672              No Rez for the Weary
# 673     Confession of Hope | Part One
# 674                  The Watchful Eye
# 675                     Into the Fray
# 676                  Struck by Wonder
# 677     Confession of Hope | Part Two
# 678                  A Hero's Requiem
# 679                From Fallen Ground
# 680  Ghost Community Theater Presents
# 681             Difference of Opinion
# 682               Protector of Ghosts
# 683                             Savin
# 684                       Pulled Pork
# 685         Who Guards the Guardians?
# 686       Whether Windmills or Cranes
# 687            Batteries Not Included
# 688                To Map the Unknown
# ...

# %%
title_list = list(destiny_df.loc[666:701,'title'])
display(title_list)
# Out:
# ['Pressure',
#  'Ghost Hunter',
#  "The Chosen's Choice",
#  'The We Before Us',
#  "Don't Call Me Ghost",
#  'Compliments',
#  'No Rez for the Weary',
#  'Confession of Hope | Part One',
#  'The Watchful Eye',
#  'Into the Fray',
#  'Struck by Wonder',
#  'Confession of Hope | Part Two',
#  "A Hero's Requiem",
#  'From Fallen Ground',
#  'Ghost Community Theater Presents',
#  'Difference of Opinion',
#  'Protector of Ghosts',
#  'Savin',
#  'Pulled Pork',
#  'Who Guards the Guardians?',
#  'Whether Windmills or Cranes',
#  'Batteries Not Included',
#  'To Map the Unknown',
#  'Splinter of Bone',
#  'Less Is More',
#  'Roll Call',
#  'Job Undone',
#  'Some Kind of Luck',
#  'Overestimation',
#  'Unknown Space',
#  'Two Cells',
#  'Reacquaintance',
#  'Revolution',
#  'The Spark',
#  'Chain of Souls',
#  'Where Loyalty Lies']

# %%
destiny_df.loc[666:701,'subtitle'] = title_list

# %%
destiny_df[666:689]
# Out:
#                                 title                          subtitle  \
# 666                          Pressure                          Pressure
# 667                      Ghost Hunter                      Ghost Hunter
# 668               The Chosen's Choice               The Chosen's Choice
# 669                  The We Before Us                  The We Before Us
# 670               Don't Call Me Ghost               Don't Call Me Ghost
# 671                       Compliments                       Compliments
# 672              No Rez for the Weary              No Rez for the Weary
# 673     Confession of Hope | Part One     Confession of Hope | Part One
# 674                  The Watchful Eye                  The Watchful Eye
# 675                     Into the Fray                     Into the Fray
# 676                  Struck by Wonder                  Struck by Wonder
# 677     Confession of Hope | Part Two     Confession of Hope | Part Two
# ...

# %%
#title
destiny_df.loc[666:688,'title'] = 'Book: Ghost Stories'

# %%
# page Book: Ghost Stories'
best_timestamp = 4128 +1
for i in range(666,688+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
destiny_df[688:702]
# Out:
#                    title            subtitle  \
# 688  Book: Ghost Stories  To Map the Unknown
# 689     Splinter of Bone    Splinter of Bone
# 690         Less Is More        Less Is More
# 691            Roll Call           Roll Call
# 692           Job Undone          Job Undone
# 693    Some Kind of Luck   Some Kind of Luck
# 694       Overestimation      Overestimation
# 695        Unknown Space       Unknown Space
# 696            Two Cells           Two Cells
# 697       Reacquaintance      Reacquaintance
# 698           Revolution          Revolution
# 699            The Spark           The Spark
# 700       Chain of Souls      Chain of Souls
# 701   Where Loyalty Lies  Where Loyalty Lies
#
#                                            description timestamp  keywords
# 688  His neck snaps. He's dead on impact. I get him...      4151       NaN
# 689  Deep in the heart of the Prison of Elders, Var...       NaT       NaN
# ...

# %%
#title
destiny_df.loc[689:701,'title'] = 'Book: Most Loyal'

# %%
# page Book: Ghost Stories'
best_timestamp = 4151 +1
for i in range(689,701+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %%
destiny_df[763:778]
# Out:
#                title subtitle  \
# 763       First Wish
# 764      Second Wish
# 765       Third Wish
# 766      Fourth Wish
# 767       Fifth Wish
# 768       Sixth Wish
# 769     Seventh Wish
# 770      Eighth Wish
# 771       Ninth Wish
# 772       Tenth Wish
# 773    Eleventh Wish
# 774     Twelfth Wish
# 775  Thirteenth Wish
# 776  Fourteenth Wish
# 777   Fifteenth Wish
#
#                                            description timestamp  keywords
# 763                       A wish to feed an addiction.       NaT       NaN
# 764                    A wish for material validation.       NaT       NaN
# 765       A wish for others to celebrate your success.       NaT       NaN
# 766               A wish to look athletic and elegant.       NaT       NaN
# 767                     A wish for a promising future.       NaT       NaN
# 768                  A wish to move the hands of time.       NaT       NaN
# 769                   A wish to help a friend in need.       NaT       NaN
# ...

# %%
title_list = list(destiny_df.loc[763:777, 'title'])

# %%
destiny_df.loc[763:777,'subtitle'] = title_list

# %%
# title
destiny_df.loc[763:777,'title'] = 'Book: Wall of Wishes'

# %%
# page 'Book: Wall of Wishes'
best_timestamp = 4164 +1
for i in range(763,777+1):
    destiny_df.loc[i,'timestamp'] = best_timestamp
    best_timestamp += 1

# %% [markdown]
# ## ITEMS season 4~5

# %%
destiny_df[777:801]
# Out:
#                           title  \
# 777        Book: Wall of Wishes
# 778             Aeviternal XXII
# 779              Death to Kells
# 780              Unfinal Shapes
# 781               The Tall Tale
# 782                    Hecuba-S
# 783             Warrior's Steed
# 784              Ravager's Ride
# 785    Peerless Precision Shell
# 786            S.H.A.N.K. Shell
# 787                Tyrant Shell
# 788  Sanctified Vigilance Shell
# 789      Way of a Thousand Cuts
# 790          Way of the Current
# 791           Way of the Wraith
# 792      Code of the Devastator
# 793         Code of the Missile
# 794       Code of the Commander
# 795         Attunement of Grace
# 796       Attunement of Control
# 797       Attunement of Fission
# 798                 Luna's Howl
# 799                  Tigerspite
# 800                Waking Vigil
#
#                                               subtitle  \
# 777                                     Fifteenth Wish
# ...

# %%
destiny_df.loc[778:788,'timestamp'] = 4000
destiny_df.loc[798:800,'timestamp'] = 4000

# %%
# 800 ~ 850
destiny_df[800:851]
# Out:
#                      title                                           subtitle  \
# 800           Waking Vigil  "We have a duty to this solar system that goes...
# 801              Sleepless  "I see our path ahead, full of despair and har...
# 802              Vouchsafe  "We knew it would not be easy." —Paladin Halla...
# 803          Twilight Oath  Engraved in illuminated letters on the weapon'...
# 804       Abide the Return  "It is what she asks of us." —Paladin Kamala Rior
# 805           Ether Doctor                  "Control the supply." —The Spider
# 806              Thin Line         Sometimes you forget which side you're on.
# 807    Wrong Side of Right            The right thing, for the wrong reasons.
# 808    Right Side of Wrong                                Where do you stand?
# 809        Dust Rock Blues  "No job too tough, if the price is good." —Ren...
# 810        Trackless Waste           "No footprints out here." —Olu Alderdice
# ...

# %%
destiny_df.loc[801:822,'timestamp'] = 4000
destiny_df.loc[823:824,'timestamp'] = 5000
destiny_df.loc[825:832,'timestamp'] = 4600
destiny_df.loc[834:850,'timestamp'] = 4000

# %%
# 850 ~ 900
destiny_df[851:901]
# Out:
#                             title  \
# 851        Reverie Dawn Gauntlets
# 852            Reverie Dawn Plate
# 853             Reverie Dawn Mark
# 854             Reverie Dawn Helm
# 855          Reverie Dawn Greaves
# 856           Reverie Dawn Gloves
# 857           Reverie Dawn Tabard
# 858             Reverie Dawn Bond
# 859             Reverie Dawn Hood
# 860            Reverie Dawn Boots
# 861            Scatterhorn Grasps
# 862              Scatterhorn Vest
# 863             Scatterhorn Cloak
# 864              Scatterhorn Mask
# 865           Scatterhorn Strides
# 866         Scatterhorn Gauntlets
# 867             Scatterhorn Plate
# 868              Scatterhorn Mark
# 869              Scatterhorn Helm
# 870           Scatterhorn Greaves
# 871             Scatterhorn Wraps
# 872              Scatterhorn Robe
# 873              Scatterhorn Bond
# 874              Scatterhorn Hood
# 875             Scatterhorn Boots
# 876       Grips of the Great Hunt
# ...

# %%
destiny_df.loc[851:875,'timestamp'] = 4000
destiny_df.loc[876:890,'timestamp'] = 4600
destiny_df.loc[891:900,'timestamp'] = 4000

# %%
# 900 ~ 950
destiny_df[901:951]
# Out:
#                                    title  \
# 901            Ancient Apocalypse Gloves
# 902             Ancient Apocalypse Robes
# 903              Ancient Apocalypse Bond
# 904              Ancient Apocalypse Hood
# 905             Ancient Apocalypse Boots
# 906                 Cloak of Remembrance
# 907                  Mark of Remembrance
# 908                  Bond of Remembrance
# 909                       Wing Contender
# 910                      Wing Discipline
# 911                         Wing Theorem
# 912                          Thunderlord
# 913
# 914        Just Another Day at the Tower
# 915                        Loss of Light
# 916                       Hiding at Home
# 917                       The New Normal
# 918                       The Good Fight
# 919                             Last Day
# 920                            Caretaker
# 921                      Invisible Scars
# 922          You Can Never Go Home Again
# 923                          Le Monarque
# ...

# %%
destiny_df.loc[901:912,'timestamp'] = 4000
destiny_df.loc[924:927,'timestamp'] = 5000
destiny_df.loc[930,'timestamp'] = 5000
destiny_df.loc[931,'timestamp'] = 5700

# %% [markdown]
# ## Book Season 5

# %%
destiny_df[914:923]
# Out:
#                              title subtitle  \
# 914  Just Another Day at the Tower
# 915                  Loss of Light
# 916                 Hiding at Home
# 917                 The New Normal
# 918                 The Good Fight
# 919                       Last Day
# 920                      Caretaker
# 921                Invisible Scars
# 922    You Can Never Go Home Again
#
#                                            description timestamp  keywords
# 914  The arched eyebrow spoke volumes.\n\nEva Levan...       NaT       NaN
# 915  "Valentina! And her son, Luis! Peregrine distr...       NaT       NaN
# 916  Eva checked the time on the small comms unit s...       NaT       NaN
# 917  Just getting to the outskirts of the City was ...       NaT       NaN
# 918  "Abuela? Ma'am?"\n\nIt was quiet, almost a whi...       NaT       NaN
# 919  Eva, for the second time in as many minutes, s...       NaT       NaN
# 920  Eva Levante stood leaning against the ivy-cove...       NaT       NaN
# ...

# %%
title_list = list(destiny_df.loc[914:923,'title'])

# %%
destiny_df.loc[914:923,'subtitle'] = title_list

# %%
# book title
destiny_df.loc[914:923,'title'] = 'Book: Eva\'s Journey'

# %%
# page
start_timestamp = 5100 + 1
for i in range(914,923+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
title_list = list(destiny_df.loc[932:964,'title'])

# %%
destiny_df.loc[932:964,'subtitle'] = title_list

# %%
# title
destiny_df.loc[932:940,'title'] = 'Book: The Book of Unmaking'

# %%
#pages
start_timestamp = 5110 +1
for i in range(932,940+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[941:946,'title'] = 'Book: Letters from a Renegade'

# %%
#pages
start_timestamp = 5120 +1
for i in range(941,946+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[947:964,'title'] = 'Book: The Black Armory Papers'

# %%
#pages
start_timestamp = 5130 +1
for i in range(947,964+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
title_list = list(destiny_df.loc[969:990, 'title'])

# %%
destiny_df.loc[969:990,'subtitle'] = title_list

# %%
# title
destiny_df.loc[969:990,'title'] = 'Book: Dawning Delights'

# %%
#pages
start_timestamp = 5150 +1
for i in range(969,990+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
destiny_df[932:991]
# Out:
#                              title                             subtitle  \
# 932     Book: The Book of Unmaking                             I: Cages
# 933     Book: The Book of Unmaking                          II: Freedom
# 934     Book: The Book of Unmaking                            III: Self
# 935     Book: The Book of Unmaking                         IV: Whispers
# 936     Book: The Book of Unmaking                           V: Purpose
# 937     Book: The Book of Unmaking                            VI: Focus
# 938     Book: The Book of Unmaking                         VII: Joining
# 939     Book: The Book of Unmaking                        VIII: Secrets
# 940     Book: The Book of Unmaking                          IX: Embrace
# 941  Book: Letters from a Renegade    I: An Introduction to Consequence
# 942  Book: Letters from a Renegade  II: For Fear of the Conquering Hero
# 943  Book: Letters from a Renegade                   III: A Fire Inside
# ...

# %% [markdown]
# ## ITEMS season5

# %%
destiny_df[991:1004]
# Out:
#                      title                                           subtitle  \
# 991       unsecured/OUTCRY  COMPILING latest [θ] intelligence… Insufficien...
# 992      Ada-1's Lone Wolf  "It's an old-fashioned oxymoron. There is no s...
# 993                Ódrerir  "Kinsmen to kinsmen should be true." —The Saga...
# 994           Glad Tidings  "This may be the 'Last Safe City,' but we've s...
# 995              Home Away  We celebrate the Dawning no matter what's unde...
# 996   Approaching Infinity                          The limit does not exist.
# 997             Dark Horse  There's no recognizable maker's mark. Just a "...
# 998                Burnout  Fight fire with fire. And fight everything els...
# 999             The Bronco     "A man's only as good as his ride." —Tex 99-40
# 1000         Dawning Cheer           Some traditions are too good to be true.
# 1001   Vanguard Dare Cloak  Course you gotta jack their stuff. That's how ...
# ...

# %%
destiny_df.loc[991:1003,'timestamp'] = 5000

# %% [markdown]
# ## books Season6

# %%
title_list = list(destiny_df.loc[1004:1063,'title'])

# %%
destiny_df.loc[1004:1063,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1004:1012,'title'] = 'Book: A Man with No Name'

# %%
# page
start_timestamp = 6100 + 1
for i in range(1004,1012+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[1013:1021,'title'] = 'Book: Dust'

# %%
# page
start_timestamp = 6110 + 1
for i in range(1013,1021+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[1022:1030,'title'] = 'Book: For Every Rose, a Thorn'

# %%
# page
start_timestamp = 6120 + 1
for i in range(1022,1030+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[1031:1039,'title'] = 'Book: Stolen Intelligence'

# %%
# page
start_timestamp = 6130 + 1
for i in range(1031,1039+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[1040:1048,'title'] = 'Book: Ecdysis'

# %%
# page
start_timestamp = 6140 + 1
for i in range(1040,1048+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# title
destiny_df.loc[1049:1063,'title'] = 'Book: The Warlock Aunor'

# %%
# page
start_timestamp = 6150 + 1
for i in range(1049,1063+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
destiny_df[1004:1064]
# Out:
#                               title                     subtitle  \
# 1004       Book: A Man with No Name               Heaven or Hell
# 1005       Book: A Man with No Name                        Dogma
# 1006       Book: A Man with No Name                  Home, pt. I
# 1007       Book: A Man with No Name                 Home, pt. II
# 1008       Book: A Man with No Name                Home, pt. III
# 1009       Book: A Man with No Name                 Home, pt. IV
# 1010       Book: A Man with No Name            Loose Ends, pt. I
# 1011       Book: A Man with No Name           Loose Ends, pt. II
# 1012       Book: A Man with No Name          Loose Ends, pt. III
# 1013                     Book: Dust                  The Red Box
# 1014                     Book: Dust                   The Stacks
# 1015                     Book: Dust                     The Bone
# 1016                     Book: Dust                     The Kell
# ...

# %% [markdown]
# ## ITEMS Season 6

# %%
destiny_df[1063:1101]
# Out:
#                             title  \
# 1063      Book: The Warlock Aunor
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072                     Arbalest
# 1073           Outbreak Perfected
# 1074                        Thorn
# 1075         Illicit Reaper Cloak
# 1076        Outlawed Reaper Cloak
# 1077       Notorious Reaper Cloak
# 1078          Illicit Reaper Mark
# 1079         Outlawed Reaper Mark
# 1080        Notorious Reaper Mark
# 1081          Illicit Reaper Bond
# 1082         Outlawed Reaper Bond
# 1083        Notorious Reaper Bond
# 1084         Neoteric Kiyot Cloak
# 1085                Sunbreak Mark
# 1086  Bond of the Cormorant Blade
# 1087                 21% Delirium
# 1088                  The Recluse
# 1089                   Oxygen SR3
# 1090             Liar's Handshake
# 1091                   Stronghold
# 1092               Getaway Artist
# 1093           Fallen Transponder
# 1094               Khepri's Sting
# 1095               Shadow's Grips
# ...

# %%
destiny_df.loc[1072:1093,'timestamp'] = 6000

# %% [markdown]
# ## ITEMS Season 7

# %%
destiny_df.loc[1094,'timestamp'] = 7000
destiny_df.loc[1095:1099,'timestamp'] = 7600
destiny_df.loc[1100,'timestamp'] = 7000

# %%
# 1100 ~ 1150
destiny_df[1101:1151]
# Out:
#                                           title  \
# 1101                       Opulent Stalker Vest
# 1102                      Opulent Stalker Cloak
# 1103                       Opulent Stalker Mask
# 1104                    Opulent Stalker Strides
# 1105                          Peregrine Greaves
# 1106                         Shadow's Gauntlets
# 1107                             Shadow's Plate
# 1108                             Penumbral Mark
# 1109                              Shadow's Helm
# 1110                           Shadow's Greaves
# 1111                  Opulent Duelist Gauntlets
# 1112                      Opulent Duelist Plate
# 1113                       Opulent Duelist Mark
# 1114                       Opulent Duelist Helm
# 1115                    Opulent Duelist Greaves
# 1116                            Astrocyte Verse
# 1117                            Shadow's Gloves
# 1118                             Shadow's Robes
# ...

# %%
destiny_df.loc[1101:1105,'timestamp'] = 7000
destiny_df.loc[1106:1110,'timestamp'] = 7600
destiny_df.loc[1111:1116,'timestamp'] = 7000
destiny_df.loc[1117:1121,'timestamp'] = 7600
destiny_df.loc[1122:1145,'timestamp'] = 7000

# %% [markdown]
# ## book Season7

# %%
destiny_df[1146:1180]
# Out:
#                                           title  \
# 1146    The Eternal Chain and the Other's Prize
# 1147  Elegy for Callum Sol and Callum's Refrain
# 1148                            The Liar's Trap
# 1149                         The Darkest Shadow
# 1150                 A New Legend to Guide Them
# 1151                                The Culling
# 1152                    The Brilliance of Bloom
# 1153                           The Long Goodbye
# 1154                              Final Whisper
# 1155                                    Entry I
# 1156                                   Entry II
# 1157                                  Entry III
# 1158                                   Entry IV
# 1159                                    Entry V
# 1160                                   Entry VI
# 1161                                  Entry VII
# 1162                                 Entry VIII
# 1163                                   Entry IX
# ...

# %%
title_list = list(destiny_df.loc[1146:1178,'title'])

# %%
destiny_df.loc[1146:1178,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1146:1178,'title'] = 'Book: The Chronicon'

# %%
# page
start_timestamp = 7100 + 1
for i in range(1146,1178+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %% [markdown]
# ## ITEMS Season 8

# %%
destiny_df[1179:1207]
# Out:
#                         title  \
# 1179           Phoenix Cradle
# 1180          Assassin's Cowl
# 1181      Stormdancer's Brace
# 1182    Helm of Righteousness
# 1183  Gauntlets of Exaltation
# 1184   Plate of Transcendence
# 1185        Temptation's Mark
# 1186    Greaves of Ascendancy
# 1187     Gloves of Exaltation
# 1188   Robes of Transcendence
# 1189        Temptation's Bond
# 1190    Mask of Righteousness
# 1191      Boots of Ascendancy
# 1192      Grips of Exaltation
# 1193    Vest of Transcendence
# 1194      Cloak of Temptation
# 1195    Cowl of Righteousness
# 1196    Strides of Ascendancy
# 1197       Never Live It Down
# 1198       Leviathan's Breath
# 1199             Eriana's Vow
# 1200                Xenophage
# 1201             Deathbringer
# 1202                 Divinity
# 1203              Monte Carlo
# 1204                  Heretic
# 1205                 Apostate
# 1206               Blasphemer
#
#                                                subtitle  \
# ...

# %%
destiny_df.loc[1179:1181,'timestamp'] = 8000
destiny_df.loc[1182:1196,'timestamp'] = 8600
destiny_df.loc[1197:1203,'timestamp'] = 8000
destiny_df.loc[1204:1206,'timestamp'] = 8700

# %% [markdown]
# ## Book Season 8

# %%
destiny_df[1207:1258]
# Out:
#                                title subtitle  \
# 1207             Pleased to Meet You
# 1208           Gardener and Winnower
# 1209                 The Flower Game
# 1210                 The Final Shape
# 1211                 The First Knife
# 1212                             p53
# 1213                           T = 0
# 1214          The Cambrian Explosion
# 1215                     Patternfall
# 1216                       The Wager
# 1217                  Trust and Hope
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227                          Realis
# 1228                        Mirative
# 1229                          Gnomic
# 1230                       Epistemic
# 1231                         Deontic
# 1232                          Atelic
# 1233                         Jussive
# 1234                        Volitive
# 1235                        Irrealis
# 1236          The Sixth Seal, Part I
# 1237         The Sixth Seal, Part II
# ...

# %%
title_list = list(destiny_df.loc[1207:1217,'title'])
destiny_df.loc[1207:1217,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1207:1217,'title'] = 'Book: Unveiling'

# %%
# page
start_timestamp = 8100 + 1
for i in range(1207,1217+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
title_list = list(destiny_df.loc[1227:1244,'title'])
destiny_df.loc[1227:1244,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1227:1235,'title'] = 'Book: Aspect'
destiny_df.loc[1236:1244,'title'] = 'Book: Last Days on Kraken Mare'

# %%
# page
start_timestamp = 8111 + 1
for i in range(1227,1244+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
destiny_df[1252:1317]
# Out:
#                              title subtitle  \
# 1252                   Moon Mining
# 1253                 The Discovery
# 1254                Noetic Effects
# 1255         The Deep-Space Signal
# 1256                      Detached
# ...                            ...      ...
# 1312   Regarding Zydron, Gate Lord
# 1313         Regarding the Fanatic
# 1314  Regarding Crota, Son of Oryx
# 1315         Regarding the Pyramid
# 1316
#
#                                             description timestamp  keywords
# 1252  RECORD: 0303K785$LUN-0.024\nIDENTITIES: [SCRUB...       NaN       NaN
# 1253  RECORD: 6782W671$LUN-0.167\nIDENTITIES: Dr. Ta...       NaN       NaN
# 1254  RECORD: 8796T563$LUN-0.324 [RECUSAL MIRROR REC...       NaN       NaN
# 1255  RECORD: 9046G766$LUN-0.346 [RECUSAL MIRROR REC...       NaN       NaN
# 1256  RECORD: 8796T563$LUN-0.279 [RECUSAL MIRROR REC...       NaN       NaN
# ...                                                 ...       ...       ...
# ...

# %%
title_list = list(destiny_df.loc[1252:1316,'title'])
destiny_df.loc[1252:1316,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1252:1271,'title'] = 'Book: Revelation'
destiny_df.loc[1272:1291,'title'] = 'Book: Inquisition of the Damned'
destiny_df.loc[1292:1301,'title'] = 'Book: Luna\'s Lost'
destiny_df.loc[1302:1315,'title'] = 'Book: Letters from Eris'

# %%
# page
start_timestamp = 8129 + 1
for i in range(1252,1315+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %% [markdown]
# ## ITEMS Season 9

# %%
destiny_df[1317:1339]
# Out:
#                       title  \
# 1317        The Bombardiers
# 1318        Promethium Spur
# 1319    Severance Enclosure
# 1320            Amnestia-S2
# 1321       Sleepless Flight
# 1322
# 1323          Chrysopelea-S
# 1324               The Prod
# 1325              Tachyon-4
# 1326     Saint's Invocation
# 1327           Devil's Ruin
# 1328                Bastion
# 1329               Symmetry
# 1330  Steelfeather Repeater
# 1331         Gallant Charge
# 1332   Martyr's Retribution
# 1333       Line in the Sand
# 1334  Patron of Lost Causes
# 1335            Breachlight
# 1336             Komodo-4FR
# 1337                 Python
# 1338                Buzzard
#
#                                                subtitle  \
# 1317  "Tallulah Fairwind never turns down a dare." —...
# 1318                   Pass the torch. Spread the fire.
# 1319  The loop is made. Over and over until the coll...
# 1320      "The Dawning welcomes everyone." —Eva Levante
# ...

# %%
destiny_df.loc[1317:1321,'timestamp'] = 9000
destiny_df.loc[1323:1338,'timestamp'] = 9000

# %% [markdown]
# ## book Season 9

# %%
destiny_df[1339:1367]
# Out:
#                                  title                   subtitle  \
# 1339  Book: The Pigeon and the Phoenix           1: Burden Part I
# 1340  Book: The Pigeon and the Phoenix          2: Burden Part II
# 1341  Book: The Pigeon and the Phoenix         3: Burden Part III
# 1342  Book: The Pigeon and the Phoenix   4: Moths to Flame Part I
# 1343  Book: The Pigeon and the Phoenix  5: Moths to Flame Part II
# 1344  Book: The Pigeon and the Phoenix      6: Foundations Part I
# 1345  Book: The Pigeon and the Phoenix     7: Foundations Part II
# 1346  Book: The Pigeon and the Phoenix         8: Observer Effect
# 1347  Book: The Pigeon and the Phoenix                    9: Thin
# 1348  Book: The Pigeon and the Phoenix            10: War Stories
# 1349  Book: The Pigeon and the Phoenix                11: Breathe
# 1350  Book: The Pigeon and the Phoenix         12: Margins Part I
# 1351  Book: The Pigeon and the Phoenix        13: Margins Part II
# ...

# %%
# title -> subtitleS
title_list = list(destiny_df.loc[1339:1366,'title'])
destiny_df.loc[1339:1366,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1339:1357,'title'] = 'Book: The Pigeon and the Phoenix'
destiny_df.loc[1358:1366,'title'] = 'Book: Constellations'

# %%
# page
start_timestamp = 9100 + 1
for i in range(1339,1357+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 9120 + 1
for i in range(1358,1366+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %% [markdown]
# ## ITEMS Season 10

# %%
destiny_df[1367:1394]
# Out:
#                          title  \
# 1367           Raiju's Harness
# 1368       Seventh Seraph Vest
# 1369       Seventh Seraph Cowl
# 1370      Seventh Seraph Grips
# 1371    Seventh Seraph Strides
# 1372      Seventh Seraph Cloak
# 1373       Seventh Seraph Mark
# 1374    Seventh Seraph Greaves
# 1375      Seventh Seraph Plate
# 1376  Seventh Seraph Gauntlets
# 1377     Seventh Seraph Helmet
# 1378       Seventh Seraph Hood
# 1379      Seventh Seraph Robes
# 1380     Seventh Seraph Gloves
# 1381      Seventh Seraph Boots
# 1382       Seventh Seraph Bond
# 1383          Felwinter's Helm
# 1384          Citan's Ramparts
# 1385                 Tatarstan
# 1386            Obsidian Wings
# 1387          Waking Nightmare
# 1388      NS81 Reprisal Sprint
# 1389               Solar Sails
# 1390             Arrow of Time
# 1391          Saint's Vocation
# 1392              The Underdog
# 1393               Team Spirit
#
#                                                subtitle  \
# ...

# %%
destiny_df.loc[1367:1393,'timestamp'] = 10000

# %%
destiny_df[1416:1426]
# Out:
#                     title                                           subtitle  \
# 1416      Felwinter's Lie  "I just like the name. Doesn't mean anything."...
# 1417        Heir Apparent         "The Red Legion will march again." —Caiatl
# 1418    Tommy's Matchbook                               "It's warm in here."
# 1419  The Fourth Horseman      It's not a holdout weapon; it's a pathfinder.
# 1420           Eye of Sol  "The sun took my sight; thus, the sun became m...
# 1421    Tomorrow's Answer              Could you please repeat the question?
# 1422       Astral Horizon           Even the brightest stars eventually set.
# 1423          The Scholar  You can't pull an all-nighter when the sun nev...
# 1424         The Summoner                  Join the dance of fire and birth.
# 1425        Exile's Curse                       It's a blessing in disguise.
#
#                                             description timestamp  keywords
# ...

# %%
destiny_df.loc[1416:1425,'timestamp'] = 10000

# %% [markdown]
# ## book Season 10

# %%
destiny_df[1394:1416]
# Out:
#                                     title subtitle  \
# 1394              Chapter 1 – Insti|gate|
# 1395               Chapter 2 – Postexilic
# 1396  Chapter 3 – The Cult of Personality
# 1397              Chapter 4 - Reflections
# 1398               Chapter 5 – [Ambition]
# 1399                 Chapter 6 – Beguiled
# 1400               Chapter 7 - Nyctalopia
# 1401                 Chapter 8 - Idolatry
# 1402                Chapter 9 – In|spire|
# 1403             1. THE BEGINNING, PART I
# 1404            2. THE BEGINNING, PART II
# 1405                          3. THE NAME
# 1406                     4. THE ASSAILANT
# 1407                        5. THE BUNKER
# 1408                      6. THE MOUNTAIN
# 1409                       7. THE WARLORD
# 1410                        8. THE SEARCH
# 1411                  9. SIDDHARTHA GOLEM
# 1412                    10. THE DISCOVERY
# 1413                    11. THE IRON LORD
# 1414                         12. THE LURE
# ...

# %%
title_list = list(destiny_df.loc[1394:1415,'title'])
destiny_df.loc[1394:1415,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1394:1402,'title'] = 'Book: Trials and Tribulations'
destiny_df.loc[1403:1415,'title'] = 'Book: The Liar'

# %%
# page
start_timestamp = 10100 + 1
for i in range(1394,1402+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 10110 + 1
for i in range(1403,1415+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
destiny_df[1416:1466]
# Out:
#                                            title  \
# 1416                             Felwinter's Lie
# 1417                               Heir Apparent
# 1418                           Tommy's Matchbook
# 1419                         The Fourth Horseman
# 1420                                  Eye of Sol
# 1421                           Tomorrow's Answer
# 1422                              Astral Horizon
# 1423                                 The Scholar
# 1424                                The Summoner
# 1425                               Exile's Curse
# 1426                          No Time to Explain
# 1427                                    Hawkmoon
# 1428                                 Cloudstrike
# 1429                                  The Lament
# 1430                            Eyes of Tomorrow
# 1431                                     Duality
# 1432                            Salvation's Grip
# 1433                           Deafening Whisper
# ...

# %% [markdown]
# ## ITEMS Season 12

# %%
destiny_df[1426:1443]
# Out:
#                    title                                           subtitle  \
# 1426  No Time to Explain  A single word etched onto the inside of the we...
# 1427            Hawkmoon  Stalk thy prey and let loose thy talons upon t...
# 1428         Cloudstrike  They return to moons devoid. Their eyes search...
# 1429          The Lament  The last thing the Vex ever heard—the grinding...
# 1430    Eyes of Tomorrow  "I want to see it all, unhindered, and know it...
# 1431             Duality  "The question becomes whether or not to fire, ...
# 1432    Salvation's Grip  "I respect what I cannot steal from and you ca...
# 1433   Deafening Whisper  "The right message is loud at any volume." —Os...
# 1434     Corsair's Wrath  "We are only briefly Awoken. The rest of exist...
# 1435       Friction Fire                 Speed, heat, and Light. Fire away.
# 1436              Adored  An Earth artifact, refashioned to suit the Spi...
# ...

# %%
destiny_df.loc[1426:1442,'timestamp'] = 12000
destiny_df.loc[1430,'timestamp'] = 12600

# %% [markdown]
# ## book Season 12

# %%
title_list = list(destiny_df.loc[1443:1517,'title'])
destiny_df.loc[1443:1517,'subtitle'] = title_list

# %%
# title
destiny_df.loc[1443:1456,'title'] = 'Book: The Once-Shipstealer'
destiny_df.loc[1457:1464,'title'] = 'Book: Call of the Cryptolith'
destiny_df.loc[1465:1473,'title'] = 'Book: Bray Lab Records - CONFIDENTIAL'
destiny_df.loc[1474:1482,'title'] = 'Book: Your Friend, Micah Abram'
destiny_df.loc[1483:1492,'title'] = 'Book: Legacy\'s Lament'
destiny_df.loc[1493:1501,'title'] = 'Book: The Dark Future'
destiny_df.loc[1502:1510,'title'] = 'Book: Regarding Stasis'
destiny_df.loc[1511:1517,'title'] = 'Book: A Tangled Web'

# %%
# page
start_timestamp = 12100 + 1
for i in range(1443,1456+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12120 + 1
for i in range(1457,1464+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12130 + 1
for i in range(1465,1473+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12140 + 1
for i in range(1474,1482+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12150 + 1
for i in range(1483,1492+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12170 + 1
for i in range(1493,1501+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12180 + 1
for i in range(1502,1510+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
# page
start_timestamp = 12190 + 1
for i in range(1511,1517+1):
    destiny_df.loc[i,'timestamp'] = start_timestamp
    start_timestamp += 1

# %%
destiny_df[1443:1501]
# Out:
#                                       title  \
# 1443             Book: The Once-Shipstealer
# 1444             Book: The Once-Shipstealer
# 1445             Book: The Once-Shipstealer
# 1446             Book: The Once-Shipstealer
# 1447             Book: The Once-Shipstealer
# 1448             Book: The Once-Shipstealer
# 1449             Book: The Once-Shipstealer
# 1450             Book: The Once-Shipstealer
# 1451             Book: The Once-Shipstealer
# 1452             Book: The Once-Shipstealer
# 1453             Book: The Once-Shipstealer
# 1454             Book: The Once-Shipstealer
# 1455             Book: The Once-Shipstealer
# 1456             Book: The Once-Shipstealer
# 1457           Book: Call of the Cryptolith
# 1458           Book: Call of the Cryptolith
# 1459           Book: Call of the Cryptolith
# 1460           Book: Call of the Cryptolith
# 1461           Book: Call of the Cryptolith
# 1462           Book: Call of the Cryptolith
# ...

# %% [markdown]
# ## ITEMS Season 12

# %%
destiny_df[1518:1569]
# Out:
#                       title  \
# 1518         Mask of Bakris
# 1519       Athrys's Embrace
# 1520         Icefall Mantle
# 1521         Precious Scars
# 1522            Dawn Chorus
# 1523          Necrotic Grip
# 1524       Wild Hunt Grasps
# 1525         Wild Hunt Vest
# 1526        Wild Hunt Cloak
# 1527         Wild Hunt Mask
# 1528      Wild Hunt Strides
# 1529   Calamity Rig Sleeves
# 1530      Calamity Rig Vest
# 1531     Calamity Rig Cloak
# 1532      Calamity Rig Mask
# 1533   Calamity Rig Strides
# 1534    Legacy's Oath Grips
# 1535     Legacy's Oath Vest
# 1536    Legacy's Oath Cloak
# 1537     Legacy's Oath Mask
# 1538  Legacy's Oath Strides
# 1539   Cinder Pinion Grasps
# 1540     Cinder Pinion Vest
# 1541    Cinder Pinion Cloak
# 1542     Cinder Pinion Cowl
# 1543  Cinder Pinion Strides
# 1544   Phobos Warden Grasps
# 1545     Phobos Warden Vest
# 1546    Phobos Warden Cloak
# 1547     Phobos Warden Mask
# 1548  Phobos Warden Strides
# 1549       Wild Hunt Gloves
# ...

# %%
destiny_df.loc[1518:1568,'timestamp'] = 12000
destiny_df.loc[1534:1538,'timestamp'] = 12600
destiny_df.loc[1559:1563,'timestamp'] = 12600

# %%
destiny_df[1568:1606]
# Out:
#                         title  \
# 1568      Cinder Pinion Boots
# 1569     Phobos Warden Gloves
# 1570      Phobos Warden Robes
# 1571       Phobos Warden Bond
# 1572       Phobos Warden Cowl
# 1573      Phobos Warden Boots
# 1574      Wild Hunt Gauntlets
# 1575          Wild Hunt Plate
# 1576           Wild Hunt Mark
# 1577           Wild Hunt Helm
# 1578        Wild Hunt Greaves
# 1579   Calamity Rig Gauntlets
# 1580       Calamity Rig Plate
# 1581        Calamity Rig Mark
# 1582        Calamity Rig Helm
# 1583     Calamity Rig Greaves
# 1584  Legacy's Oath Gauntlets
# 1585      Legacy's Oath Plate
# 1586       Legacy's Oath Mark
# 1587       Legacy's Oath Helm
# 1588    Legacy's Oath Greaves
# 1589  Cinder Pinion Gauntlets
# 1590      Cinder Pinion Plate
# 1591       Cinder Pinion Mark
# 1592       Cinder Pinion Helm
# 1593    Cinder Pinion Greaves
# 1594  Phobos Warden Gauntlets
# 1595      Phobos Warden Plate
# 1596       Phobos Warden Mark
# 1597       Phobos Warden Helm
# ...

# %%
destiny_df.loc[1568:1605,'timestamp'] = 12000
destiny_df.loc[1584:1588,'timestamp'] = 12600
destiny_df.loc[1602,'timestamp'] = 12700

# %% [markdown]
# ## SAVE

# %%
destiny_df[1600:1651]
# Out:
#                              title  \
# 1600             Radiant Accipiter
# 1601              Last Flight Home
# 1602                  Starfarer 7M
# 1603                      Revenant
# 1604                      Behemoth
# 1605                   Shadebinder
# 1606             Traveler's Chosen
# 1607                Ruinous Effigy
# 1608                   Witherhoard
# 1609                   Cold Denial
# 1610                False Promises
# 1611             Temptation's Hook
# 1612               Whispering Slab
# 1613                  Hollow Words
# 1614     Solstice Cloak (Majestic)
# 1615  Solstice Cloak (Magnificent)
# 1616      Solstice Mark (Majestic)
# 1617   Solstice Mark (Magnificent)
# 1618      Solstice Bond (Majestic)
# 1619   Solstice Bond (Magnificent)
# 1620                Holdfast Cloak
# 1621                 Holdfast Bond
# 1622                 Holdfast Mark
# 1623         Crushing Guard (CODA)
# 1624          Crushing Helm (CODA)
# ...

# %%
destiny_df.to_json('../fin_project/destiny_timestamp_01_12.json', orient='records')
